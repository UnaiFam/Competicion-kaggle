# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv("DATA/train.csv")
df_test=pd.read_csv("DATA/test.csv")

# %%
df_train.head()
# Out:
#     id  laptop_ID  Company                     Product   TypeName  Inches  \
# 0  268       1002     Dell               Inspiron 5567   Notebook    15.6
# 1  347        867     Asus  X541NA (N4200/4GB/1TB/W10)   Notebook    15.6
# 2  353        966  Toshiba           Portege Z30-C-1CW   Notebook    13.3
# 3  578        767     Dell                Alienware 17     Gaming    15.6
# 4   42       1241     Dell              Latitude E7270  Ultrabook    12.5
#
#                   ScreenResolution                                   Cpu  \
# 0                         1366x768            Intel Core i7 7500U 2.7GHz
# 1                         1366x768  Intel Pentium Quad Core N4200 1.1GHz
# 2                Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 3  IPS Panel 4K Ultra HD 3840x2160           Intel Core i7 7700HQ 2.8GHz
# 4  Full HD / Touchscreen 1920x1080            Intel Core i5 6300U 2.4GHz
#
#     Ram                Memory                      Gpu       OpSys  Weight  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                912 non-null    int64
#  1   laptop_ID         912 non-null    int64
#  2   Company           912 non-null    object
#  3   Product           912 non-null    object
#  4   TypeName          912 non-null    object
#  5   Inches            912 non-null    float64
#  6   ScreenResolution  912 non-null    object
#  7   Cpu               912 non-null    object
#  8   Ram               912 non-null    object
#  9   Memory            912 non-null    object
#  10  Gpu               912 non-null    object
#  11  OpSys             912 non-null    object
#  12  Weight            912 non-null    object
#  13  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 99.9+ KB

# %%
len(df_train["id"].unique())
# Out:
# 912

# %%
len(df_train["laptop_ID"].unique())
# Out:
# 912

# %%
len(df_train["Product"].unique())
# Out:
# 475

# %% [markdown]
# Me Parece que el id es para identificar en la submission, el id lapttop seria el id proopio, y el producto el nombre del modelo

# %% [markdown]
# Vale el id es un numero para identificar el portatil.
# Hay que cambiar las siguientes columnas:
# * Company
# * TypeName
# * ScreenResolution
# * Cpu
# * Ram v
# * Memory
# * Gpu
# * OpSys
# * Weight
#
#
# Al parecer se tiene que enviar en froma de:
# id precio

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder# aunque esete eltimo esta en get dummies



df_train=pd.get_dummies(df_train, columns=['Company'], drop_first=True)
"""Company_encoder = LabelEncoder()

df_train['Company_enc'] = Company_encoder.fit_transform(df_train['Company'])
df_train"""
df_train.iloc[0]
# Out:
# id                                          268
# laptop_ID                                  1002
# Product                           Inspiron 5567
# TypeName                               Notebook
# Inches                                     15.6
# ScreenResolution                       1366x768
# Cpu                  Intel Core i7 7500U 2.7GHz
# Ram                                         8GB
# Memory                                  1TB HDD
# Gpu                          AMD Radeon R7 M445
# OpSys                                Windows 10
# Weight                                   2.36kg
# Price_euros                               749.0
# Company_Apple                             False
# Company_Asus                              False
# Company_Chuwi                             False
# Company_Dell                               True
# Company_Fujitsu                           False
# Company_Google                            False
# Company_HP                                False
# ...

# %%
Type_encoder = LabelEncoder()
df_train=pd.get_dummies(df_train, columns=['TypeName'], drop_first=True)
"""df_train['Type_enc'] = Type_encoder.fit_transform(df_train['TypeName'])"""
df_train.iloc[0]
# Out:
# id                                             268
# laptop_ID                                     1002
# Product                              Inspiron 5567
# Inches                                        15.6
# ScreenResolution                          1366x768
# Cpu                     Intel Core i7 7500U 2.7GHz
# Ram                                            8GB
# Memory                                     1TB HDD
# Gpu                             AMD Radeon R7 M445
# OpSys                                   Windows 10
# Weight                                      2.36kg
# Price_euros                                  749.0
# Company_Apple                                False
# Company_Asus                                 False
# Company_Chuwi                                False
# Company_Dell                                  True
# Company_Fujitsu                              False
# Company_Google                               False
# ...

# %%
df_train["Weight"]=df_train["Weight"].str[:-2]
df_train["Weight"]=df_train["Weight"].astype(float)

# %%
df_train.iloc[0]
# Out:
# id                                             268
# laptop_ID                                     1002
# Product                              Inspiron 5567
# Inches                                        15.6
# ScreenResolution                          1366x768
# Cpu                     Intel Core i7 7500U 2.7GHz
# Ram                                            8GB
# Memory                                     1TB HDD
# Gpu                             AMD Radeon R7 M445
# OpSys                                   Windows 10
# Weight                                        2.36
# Price_euros                                  749.0
# Company_Apple                                False
# Company_Asus                                 False
# Company_Chuwi                                False
# Company_Dell                                  True
# Company_Fujitsu                              False
# Company_Google                               False
# ...

# %%
df_train["Ram"]=df_train["Ram"].str[:-2]
df_train["Ram"]=df_train["Ram"].astype(int)
df_train.head()
# Out:
#     id  laptop_ID                     Product  Inches  \
# 0  268       1002               Inspiron 5567    15.6
# 1  347        867  X541NA (N4200/4GB/1TB/W10)    15.6
# 2  353        966           Portege Z30-C-1CW    13.3
# 3  578        767                Alienware 17    15.6
# 4   42       1241              Latitude E7270    12.5
#
#                   ScreenResolution                                   Cpu  Ram  \
# 0                         1366x768            Intel Core i7 7500U 2.7GHz    8
# 1                         1366x768  Intel Pentium Quad Core N4200 1.1GHz    4
# 2                Full HD 1920x1080            Intel Core i5 6200U 2.3GHz    8
# 3  IPS Panel 4K Ultra HD 3840x2160           Intel Core i7 7700HQ 2.8GHz   16
# 4  Full HD / Touchscreen 1920x1080            Intel Core i5 6300U 2.4GHz    8
#
#                  Memory                      Gpu       OpSys  ...  \
# 0               1TB HDD       AMD Radeon R7 M445  Windows 10  ...
# ...

# %%
df_train["OpSys"].unique()
# Out:
# array(['Windows 10', 'Windows 7', 'Linux', 'Chrome OS', 'No OS',
#        'Mac OS X', 'Windows 10 S', 'macOS', 'Android'], dtype=object)

# %%
OS_encoder = LabelEncoder()
df_train=pd.get_dummies(df_train, columns=['OpSys'], drop_first=True)
"""df_train['Sys_enc'] = OS_encoder.fit_transform(df_train['OpSys'])"""
df_train.iloc[0]
# Out:
# id                                             268
# laptop_ID                                     1002
# Product                              Inspiron 5567
# Inches                                        15.6
# ScreenResolution                          1366x768
# Cpu                     Intel Core i7 7500U 2.7GHz
# Ram                                              8
# Memory                                     1TB HDD
# Gpu                             AMD Radeon R7 M445
# Weight                                        2.36
# Price_euros                                  749.0
# Company_Apple                                False
# Company_Asus                                 False
# Company_Chuwi                                False
# Company_Dell                                  True
# Company_Fujitsu                              False
# Company_Google                               False
# Company_HP                                   False
# ...

# %%
df_test["ScreenResolution"].unique()
# Out:
# array(['IPS Panel 4K Ultra HD 3840x2160', '1366x768', 'Full HD 1920x1080',
#        'IPS Panel Full HD 1920x1080', 'Full HD / Touchscreen 1920x1080',
#        'Touchscreen 2560x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Quad HD+ / Touchscreen 3200x1800',
#        'IPS Panel Retina Display 2736x1824', 'Quad HD+ 3200x1800',
#        'IPS Panel Full HD 1366x768', 'IPS Panel Full HD 2160x1440',
#        'IPS Panel Quad HD+ 3200x1800', 'Touchscreen 2256x1504',
#        '1600x900', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Retina Display 2560x1600', '2560x1440',
#        'IPS Panel Touchscreen 1366x768',
#        'IPS Panel Retina Display 2880x1800',
#        '4K Ultra HD / Touchscreen 3840x2160', 'IPS Panel 2560x1440',
#        'IPS Panel Quad HD+ 2560x1440', 'IPS Panel Touchscreen 2560x1440',
#        '1440x900', '4K Ultra HD 3840x2160',
#        'Touchscreen / Quad HD+ 3200x1800',
# ...

# %%
import numpy as np

df_train['HD'] = np.where(df_train['ScreenResolution'].str.contains("HD"), 1, 0)
df_train['Touch'] = np.where(df_train['ScreenResolution'].str.contains("Touchscreen"), 1, 0)
df_train['IPS'] = np.where(df_train['ScreenResolution'].str.contains("IPS"), 1, 0)
df_train['4K'] = np.where(df_train['ScreenResolution'].str.contains("4K"), 1, 0)

# %%
df_train["ScreenResolution"]=df_train["ScreenResolution"].str[-9:]
df_train
# Out:
#        id  laptop_ID                     Product  Inches ScreenResolution  \
# 0     268       1002               Inspiron 5567    15.6         1366x768
# 1     347        867  X541NA (N4200/4GB/1TB/W10)    15.6         1366x768
# 2     353        966           Portege Z30-C-1CW    13.3        1920x1080
# 3     578        767                Alienware 17    15.6        3840x2160
# 4      42       1241              Latitude E7270    12.5        1920x1080
# ..    ...        ...                         ...     ...              ...
# 907    89        973       Chromebook C738T-C2EJ    11.6         1366x768
# 908   716       1018           Portege Z30-C-16H    13.3        1920x1080
# 909   517       1071              Aspire ES1-523    15.6         1366x768
# 910   891        965               Latitude 7480    14.0        1920x1080
# 911  1179       1313               Inspiron 3567    15.6         1366x768
#
#                                       Cpu  Ram                Memory  \
# ...

# %%
df_train["ScreenResolution"].unique()
# Out:
# array(['1366x768', '1920x1080', '3840x2160', '1920x1200', ' 1366x768',
#        '2880x1800', '3200x1800', '2560x1440', '1600x900', '2304x1440',
#        '1440x900', '2560x1600', '2256x1504', '2400x1600', '2160x1440'],
#       dtype=object)

# %%
Screen_encoder = LabelEncoder()

df_train['Screen_Enc'] = Screen_encoder.fit_transform(df_train['ScreenResolution'])
df_train
# Out:
#        id  laptop_ID                     Product  Inches ScreenResolution  \
# 0     268       1002               Inspiron 5567    15.6         1366x768
# 1     347        867  X541NA (N4200/4GB/1TB/W10)    15.6         1366x768
# 2     353        966           Portege Z30-C-1CW    13.3        1920x1080
# 3     578        767                Alienware 17    15.6        3840x2160
# 4      42       1241              Latitude E7270    12.5        1920x1080
# ..    ...        ...                         ...     ...              ...
# 907    89        973       Chromebook C738T-C2EJ    11.6         1366x768
# 908   716       1018           Portege Z30-C-16H    13.3        1920x1080
# 909   517       1071              Aspire ES1-523    15.6         1366x768
# 910   891        965               Latitude 7480    14.0        1920x1080
# 911  1179       1313               Inspiron 3567    15.6         1366x768
#
#                                       Cpu  Ram                Memory  \
# ...

# %%
df_train["Memory"].unique()
# Out:
# array(['1TB HDD', '256GB SSD', '256GB SSD +  1TB HDD',
#        '512GB SSD +  2TB HDD', '128GB SSD +  1TB HDD', '128GB SSD',
#        '1TB SSD', '64GB Flash Storage', '2TB HDD', '500GB HDD',
#        '1.0TB Hybrid', '16GB Flash Storage', '256GB Flash Storage',
#        '180GB SSD', '32GB Flash Storage', '512GB SSD',
#        '512GB SSD +  1TB HDD', '256GB SSD +  500GB HDD',
#        '256GB SSD +  2TB HDD', '1TB SSD +  1TB HDD', '64GB SSD',
#        '128GB Flash Storage', '256GB SSD +  1.0TB Hybrid', '32GB SSD',
#        '512GB Flash Storage', '240GB SSD', '256GB SSD +  256GB SSD',
#        '16GB SSD', '8GB SSD', '64GB Flash Storage +  1TB HDD',
#        '1.0TB HDD', '1TB HDD +  1TB HDD', '512GB SSD +  512GB SSD',
#        '128GB SSD +  2TB HDD', '32GB HDD', '512GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
condicion_hyb=[df_train['Memory'].str.contains("1TB Hybrid"),
df_train['Memory'].str.contains("1.0TB Hybrid"),
df_train['Memory'].str.contains("2TB Hybrid"),
df_train['Memory'].str.contains("2.0TB Hybrid"),
df_train['Memory'].str.contains('32GB Hybrid'),
df_train['Memory'].str.contains('16GB Hybrid'),
df_train['Memory'].str.contains('1TB Hybrid +  1TB Hybrid'),
df_train['Memory'].str.contains('1.0TB Hybrid +  1.0TB Hybrid'),
df_train['Memory'].str.contains('500GB Hybrid'),
df_train['Memory'].str.contains('2TB Hybrid +  2TB Hybrid'),
df_train['Memory'].str.contains('2.0TB Hybrid +  2.0TB Hybrid'),
df_train['Memory'].str.contains('508GB Hybrid')]
resultado_hyb=[1000,
1000,
2000,
2000,
32,
16,
2000,
2000,
500,
2000,
2000,508]

# %%
df_train['Hybrid'] = np.select(condicion_hyb, resultado_hyb, 0)
df_train['Hybrid'].unique()
# Out:
# array([   0, 1000])

# %%
condicion_HDD=[df_train['Memory'].str.contains("1TB HDD"),
df_train['Memory'].str.contains("1.0TB HDD"),
df_train['Memory'].str.contains("2TB HDD"),
df_train['Memory'].str.contains("2.0TB HDD"),
df_train['Memory'].str.contains('32GB HDD'),
df_train['Memory'].str.contains('16GB HDD'),
df_train['Memory'].str.contains('1TB HDD +  1TB HDD'),
df_train['Memory'].str.contains('1.0TB HDD +  1.0TB HDD'),
df_train['Memory'].str.contains('500GB HDD'),
df_train['Memory'].str.contains('2TB HDD +  2TB HDD'),
df_train['Memory'].str.contains('2.0TB HDD +  2.0TB HDD')]
resultado_HDD=[1000,
1000,
2000,
2000,
32,
16,
2000,
2000,
500,
2000,
2000]

# %%
df_train['HDD'] = np.select(condicion_HDD, resultado_HDD, 0)
df_train['HDD'].unique()
# Out:
# array([1000,    0, 2000,  500,   32])

# %%
df_test["Memory"].unique()
# Out:
# array(['512GB SSD', '256GB SSD', '500GB HDD', '1TB HDD', '1TB SSD',
#        '32GB Flash Storage', '128GB SSD', '128GB SSD +  1TB HDD',
#        '256GB SSD +  1TB HDD', '64GB Flash Storage',
#        '512GB SSD +  1TB HDD', '2TB HDD', '32GB SSD', '1.0TB Hybrid',
#        '128GB SSD +  2TB HDD', '256GB SSD +  256GB SSD',
#        '256GB SSD +  2TB HDD', '256GB Flash Storage',
#        '512GB SSD +  2TB HDD', '128GB HDD', '16GB Flash Storage',
#        '508GB Hybrid', '512GB SSD +  256GB SSD', '128GB Flash Storage'],
#       dtype=object)

# %%
condicion_SSD=[df_train['Memory'].str.contains("1TB SSD"),
df_train['Memory'].str.contains("1.0TB SSD"),
df_train['Memory'].str.contains("2TB SSD"),
df_train['Memory'].str.contains("2.0TB SSD"),
df_train['Memory'].str.contains('32GB SSD'),
df_train['Memory'].str.contains('16GB SSD'),
df_train['Memory'].str.contains('1TB SSD +  1TB SSD'),
df_train['Memory'].str.contains('1.0TB SSD +  1.0TB SSD'),

df_train['Memory'].str.contains('256GB SSD'),
df_train['Memory'].str.contains('180GB SSD'),
df_train['Memory'].str.contains('512GB SSD'),
df_train['Memory'].str.contains('240GB SSD'),

]
resultado_SSD=[1000,
1000,
2000,
2000,
32,
16,
2000,
2000,
256,
180,
512,
240]

# %%
df_train['SSD'] = np.select(condicion_SSD, resultado_SSD, 0)
df_train['SSD'].unique()
# Out:
# array([   0,  256,  512, 1000,  180,   32,  240,   16])

# %%
condicion_Flash=[df_train['Memory'].str.contains("1TB Flash Storage"),
df_train['Memory'].str.contains("1.0TB Flash Storage"),
df_train['Memory'].str.contains("2TB Flash Storage"),
df_train['Memory'].str.contains("2.0TB Flash Storage"),
df_train['Memory'].str.contains('32GB Flash Storage'),
df_train['Memory'].str.contains('16GB Flash Storage'),
df_train['Memory'].str.contains('1TB Flash Storage +  1TB Flash Storage'),
df_train['Memory'].str.contains('1.0TB Flash Storage +  1.0TB Flash Storage'),

df_train['Memory'].str.contains('256GB Flash Storage'),
df_train['Memory'].str.contains('180GB Flash Storage'),
df_train['Memory'].str.contains('512GB Flash Storage'),
df_train['Memory'].str.contains('240GB Flash Storage'),
df_train['Memory'].str.contains('64GB Flash Storage'),
]
resultado_Flash=[1000,
1000,
2000,
2000,
32,
16,
2000,
2000,
256,
180,
512,
240,
64]

# %%
df_train['Flash'] = np.select(condicion_Flash, resultado_Flash, 0)
df_train['Flash'].unique()
# Out:
# array([  0,  64,  16, 256,  32, 512])

# %%
df_train["Flash"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 907    32
# 908     0
# 909     0
# 910     0
# 911     0
# Name: Flash, Length: 912, dtype: int64

# %%
"""df_train['HDD'] = np.where(df_train['Memory'].str.contains("HDD"), 1, 0)
df_train['SSD'] = np.where(df_train['Memory'].str.contains("SSD"), 1, 0)

df_train['FLASH'] = np.where(df_train['Memory'].str.contains("Flash Storage"), 1, 0)"""
# Out:
# 'df_train[\'HDD\'] = np.where(df_train[\'Memory\'].str.contains("HDD"), 1, 0)\ndf_train[\'SSD\'] = np.where(df_train[\'Memory\'].str.contains("SSD"), 1, 0)\n\ndf_train[\'FLASH\'] = np.where(df_train[\'Memory\'].str.contains("Flash Storage"), 1, 0)'

# %%
df_train['Cpu'].unique()
# Out:
# array(['Intel Core i7 7500U 2.7GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
#        'Intel Core i5 6200U 2.3GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 6300U 2.4GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Pentium Quad Core N3710 1.6GHz',
#        'Intel Core i7 8550U 1.8GHz', 'AMD A9-Series A9-9420 3GHz',
#        'Intel Pentium Dual Core 4405U 2.1GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 7100U 2.4GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Xeon E3-1535M v6 3.1GHz',
#        'Intel Atom x5-Z8550 1.44GHz', 'AMD A10-Series 9620P 2.5GHz',
#        'Intel Core i5 7300U 2.6GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i7 6500U 2.5GHz', 'Intel Core i3 6006U 2.0GHz',
#        'Intel Celeron Dual Core 3205U 1.5GHz',
#        'AMD A12-Series 9720P 3.6GHz',
#        'Intel Celeron Dual Core N3050 1.6GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i5 7300HQ 2.5GHz',
# ...

# %%
df_train['Dual'] = np.where(df_train['Cpu'].str.contains("Dual"), 2, 1)
df_train['Quad'] = np.where(df_train['Cpu'].str.contains("Quad"), 3, 0)
df_train['Core']=df_train['Quad']+df_train['Dual']
df_train['Core'].unique()
# Out:
# array([1, 4, 2])

# %%
len (df_train)
# Out:
# 912

# %%
#meter h¡ghz del procesado
ghz=[]
for x in range(len (df_train)):
    ghz.append(float((df_train['Cpu'][x][::-1][3:df_train['Cpu'][x][::-1].find(" ")])[::-1]))
df_train["GHz"]=ghz
df_train.head()
# Out:
#     id  laptop_ID                     Product  Inches ScreenResolution  \
# 0  268       1002               Inspiron 5567    15.6         1366x768
# 1  347        867  X541NA (N4200/4GB/1TB/W10)    15.6         1366x768
# 2  353        966           Portege Z30-C-1CW    13.3        1920x1080
# 3  578        767                Alienware 17    15.6        3840x2160
# 4   42       1241              Latitude E7270    12.5        1920x1080
#
#                                     Cpu  Ram                Memory  \
# 0            Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 1  Intel Pentium Quad Core N4200 1.1GHz    4               1TB HDD
# 2            Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 3           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 4            Intel Core i5 6300U 2.4GHz    8             256GB SSD
#
#                        Gpu  Weight  ...  4K  Screen_Enc  Hybrid   HDD  SSD  \
# ...

# %%
ghz=df_train.apply





df_train.head()
# Out:
#     id  laptop_ID                     Product  Inches ScreenResolution  \
# 0  268       1002               Inspiron 5567    15.6         1366x768
# 1  347        867  X541NA (N4200/4GB/1TB/W10)    15.6         1366x768
# 2  353        966           Portege Z30-C-1CW    13.3        1920x1080
# 3  578        767                Alienware 17    15.6        3840x2160
# 4   42       1241              Latitude E7270    12.5        1920x1080
#
#                                     Cpu  Ram                Memory  \
# 0            Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 1  Intel Pentium Quad Core N4200 1.1GHz    4               1TB HDD
# 2            Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 3           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 4            Intel Core i5 6300U 2.4GHz    8             256GB SSD
#
#                        Gpu  Weight  ...  4K  Screen_Enc  Hybrid   HDD  SSD  \
# ...

# %%
"""Cpu_encoder = LabelEncoder()"""
df_train["Marca_Intel"]=np.where(df_train['Cpu'].str.contains("Intel"), 1, 0)
df_train["Marca_AMD"]=np.where(df_train['Cpu'].str.contains("AMD"), 1, 0)

"""df_train['CPU_enc'] = Cpu_encoder.fit_transform(df_train['Cpu'])"""
df_train
# Out:
#        id  laptop_ID  Company                     Product            TypeName  \
# 0     268       1002     Dell               Inspiron 5567            Notebook
# 1     347        867     Asus  X541NA (N4200/4GB/1TB/W10)            Notebook
# 2     353        966  Toshiba           Portege Z30-C-1CW            Notebook
# 3     578        767     Dell                Alienware 17              Gaming
# 4      42       1241     Dell              Latitude E7270           Ultrabook
# ..    ...        ...      ...                         ...                 ...
# 907    89        973     Acer       Chromebook C738T-C2EJ  2 in 1 Convertible
# 908   716       1018  Toshiba           Portege Z30-C-16H            Notebook
# 909   517       1071     Acer              Aspire ES1-523            Notebook
# 910   891        965     Dell               Latitude 7480           Ultrabook
# 911  1179       1313     Dell               Inspiron 3567            Notebook
#
# ...

# %%
condiciones=("I3", "I5", "I7", "I9")
resultados= (3,5,7,9)
df_train["Gen_Intel"]=np.select(k, s, 0)

# %%
Gpu_encoder = LabelEncoder()
df_train['GPU_enc'] = Gpu_encoder.fit_transform(df_train['Gpu'])
df_train
# Out:
#        id  laptop_ID  Company                     Product            TypeName  \
# 0     268       1002     Dell               Inspiron 5567            Notebook
# 1     347        867     Asus  X541NA (N4200/4GB/1TB/W10)            Notebook
# 2     353        966  Toshiba           Portege Z30-C-1CW            Notebook
# 3     578        767     Dell                Alienware 17              Gaming
# 4      42       1241     Dell              Latitude E7270           Ultrabook
# ..    ...        ...      ...                         ...                 ...
# 907    89        973     Acer       Chromebook C738T-C2EJ  2 in 1 Convertible
# 908   716       1018  Toshiba           Portege Z30-C-16H            Notebook
# 909   517       1071     Acer              Aspire ES1-523            Notebook
# 910   891        965     Dell               Latitude 7480           Ultrabook
# 911  1179       1313     Dell               Inspiron 3567            Notebook
#
# ...

# %%
df_train.columns
# Out:
# Index(['id', 'laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros', 'Company_enc', 'Type_enc', 'Sys_enc', 'HD', 'Touch',
#        'IPS', '4K', 'Screen_Enc', 'Hybrid', 'HDD', 'SSD', 'Flash', 'Dual',
#        'Quad', 'Core', 'GHz', 'CPU_enc', 'GPU_enc'],
#       dtype='object')

# %%
features=["id", 'Inches','Weight','Company_enc', 'Type_enc', 'Sys_enc', 'HD', 'Touch', 'Ram',
'IPS', '4K', 'Screen_Enc', 'HDD', 'SSD', 'Flash',"Hybrid",'Core', 'CPU_enc',"GHz", 'GPU_enc','Price_euros']
X=df_train[features]

X.to_csv("df_train.csv", index=False)
